# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\magar\\Downloads\\laptop_data.csv")
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.drop(columns=["Unnamed: 0"],inplace=True)

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram',
#        'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 112.1+ KB

# %%
df.shape
# Out:
# (1303, 11)

# %%
df.duplicated().sum()
# Out:
# 29

# %%
df.isnull()
# Out:
#       Company  TypeName  Inches  ScreenResolution    Cpu    Ram  Memory  \
# 0       False     False   False             False  False  False   False
# 1       False     False   False             False  False  False   False
# 2       False     False   False             False  False  False   False
# 3       False     False   False             False  False  False   False
# 4       False     False   False             False  False  False   False
# ...       ...       ...     ...               ...    ...    ...     ...
# 1298    False     False   False             False  False  False   False
# 1299    False     False   False             False  False  False   False
# 1300    False     False   False             False  False  False   False
# 1301    False     False   False             False  False  False   False
# 1302    False     False   False             False  False  False   False
#
#         Gpu  OpSys  Weight  Price
# 0     False  False   False  False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 112.1+ KB

# %%
#remove gb from ram columns
df["Ram"]=df["Ram"].str.replace("GB","")

# %%
# remove kg from weight columns
df["Weight"]=df["Weight"].str.replace("kg","")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 112.1+ KB

# %%
df["Ram"]=df["Ram"].astype("int")
df["Weight"]=df["Weight"].astype("float")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
# dtypes: float64(3), int32(1), object(7)
# memory usage: 107.0+ KB

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232
# ...

# %%
df["ScreenResolution"].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %%
# make the IPS columns from screen resolution wher ips is there make 1 else make 0
df["IPS"]=df["ScreenResolution"].apply(lambda x:1 if "IPS" in x else 0)

# %%
df.head(3)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight       Price  IPS
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832    1
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232    0
# 2         Intel HD Graphics 620  No OS    1.86  30636.0000    0

# %%
df["Touchscreen"]=df["ScreenResolution"].apply(lambda x:1 if "Touchscreen" in x else 0)

# %%
df.tail()
# Out:
#      Company            TypeName  Inches  \
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu  Ram              Memory  \
# 1298            Intel Core i7 6500U 2.5GHz    4           128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz   16           512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz    2  64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz    6             1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz    4           500GB HDD
#
# ...

# %%
var=df["ScreenResolution"].str.split("x",n=1,expand=True)
var
# Out:
#                                           0     1
# 0             IPS Panel Retina Display 2560  1600
# 1                                      1440   900
# 2                              Full HD 1920  1080
# 3             IPS Panel Retina Display 2880  1800
# 4             IPS Panel Retina Display 2560  1600
# ...                                     ...   ...
# 1298   IPS Panel Full HD / Touchscreen 1920  1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200  1800
# 1300                                   1366   768
# 1301                                   1366   768
# 1302                                   1366   768
#
# [1303 rows x 2 columns]

# %%
df["x_resolution"]=var[0]
df["y_resolution"]=var[1]

# %%
df["x_resolution"]
# Out:
# 0               IPS Panel Retina Display 2560
# 1                                        1440
# 2                                Full HD 1920
# 3               IPS Panel Retina Display 2880
# 4               IPS Panel Retina Display 2560
#                         ...
# 1298     IPS Panel Full HD / Touchscreen 1920
# 1299    IPS Panel Quad HD+ / Touchscreen 3200
# 1300                                     1366
# 1301                                     1366
# 1302                                     1366
# Name: x_resolution, Length: 1303, dtype: object

# %%
df["y_resolution"]
# Out:
# 0       1600
# 1        900
# 2       1080
# 3       1800
# 4       1600
#         ...
# 1298    1080
# 1299    1800
# 1300     768
# 1301     768
# 1302     768
# Name: y_resolution, Length: 1303, dtype: object

# %%
df["x_resolution"]=df["x_resolution"].str.findall("\d{4}")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\magar\AppData\Local\Temp\ipykernel_16776\3773254475.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df["x_resolution"]=df["x_resolution"].str.findall("\d{4}")

# %%
df["x_resolution"]=df["x_resolution"].apply(lambda x:x[0])

# %%
df["x_resolution"]
# Out:
# 0       2560
# 1       1440
# 2       1920
# 3       2880
# 4       2560
#         ...
# 1298    1920
# 1299    3200
# 1300    1366
# 1301    1366
# 1302    1366
# Name: x_resolution, Length: 1303, dtype: object

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  IPS  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832    1            0
# ...

# %%
df.drop(columns=["ScreenResolution"],inplace=True)

# %%
df.head(2)
# Out:
#   Company   TypeName  Inches                   Cpu  Ram               Memory  \
# 0   Apple  Ultrabook    13.3  Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook    13.3  Intel Core i5 1.8GHz    8  128GB Flash Storage
#
#                             Gpu  OpSys  Weight       Price  IPS  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832    1            0
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232    0            0
#
#   x_resolution y_resolution
# 0         2560         1600
# 1         1440          900

# %%
df["Cpu"].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
df["Intel"]=df["Cpu"].apply(lambda x:1 if "Intel" in x else 0)

# %%
df["AMD"]=df["Cpu"].apply(lambda x:1 if "AMD" in x else 0)

# %%
df.head(2)
# Out:
#   Company   TypeName  Inches                   Cpu  Ram               Memory  \
# 0   Apple  Ultrabook    13.3  Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook    13.3  Intel Core i5 1.8GHz    8  128GB Flash Storage
#
#                             Gpu  OpSys  Weight       Price  IPS  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832    1            0
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232    0            0
#
#   x_resolution y_resolution  Intel  AMD
# 0         2560         1600      1    0
# 1         1440          900      1    0

# %%
df.drop(columns=["Cpu"],inplace=True)

# %%
df.head(2)
# Out:
#   Company   TypeName  Inches  Ram               Memory  \
# 0   Apple  Ultrabook    13.3    8            128GB SSD
# 1   Apple  Ultrabook    13.3    8  128GB Flash Storage
#
#                             Gpu  OpSys  Weight       Price  IPS  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832    1            0
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232    0            0
#
#   x_resolution y_resolution  Intel  AMD
# 0         2560         1600      1    0
# 1         1440          900      1    0

# %%
df["Memory"].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df["SSD"]=df["Memory"].apply(lambda x:1 if "SSD" in x else 0)
df["HDD"]=df["Memory"].apply(lambda x:1 if "HDD" in x else 0)
df["Flash"]=df["Memory"].apply(lambda x:1 if "Flash" in x else 0)

# %%
df["Gpu"].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df["Intel"]=df["Gpu"].apply(lambda x:1 if "Intel" in x else 0)
df["Nvidia"]=df["Gpu"].apply(lambda x:1 if "Nvidia" in x else 0)
df["AMD"]=df["Gpu"].apply(lambda x:1 if "AMD" in x else 0)

# %%
df.head(5)
# Out:
#   Company   TypeName  Inches  Ram               Memory  \
# 0   Apple  Ultrabook    13.3    8            128GB SSD
# 1   Apple  Ultrabook    13.3    8  128GB Flash Storage
# 2      HP   Notebook    15.6    8            256GB SSD
# 3   Apple  Ultrabook    15.4   16            512GB SSD
# 4   Apple  Ultrabook    13.3    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  IPS  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832    1            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232    0            0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000    0            0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360    1            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080    1            0
#
#   x_resolution y_resolution  Intel  AMD  SSD  HDD  Flash  Nvidia
# 0         2560         1600      1    0    1    0      0       0
# ...

# %%
v=df["Gpu"].str.split(" ",n=1,expand=True)
v
# Out:
#           0                       1
# 0     Intel  Iris Plus Graphics 640
# 1     Intel        HD Graphics 6000
# 2     Intel         HD Graphics 620
# 3       AMD          Radeon Pro 455
# 4     Intel  Iris Plus Graphics 650
# ...     ...                     ...
# 1298  Intel         HD Graphics 520
# 1299  Intel         HD Graphics 520
# 1300  Intel             HD Graphics
# 1301    AMD          Radeon R5 M330
# 1302  Intel             HD Graphics
#
# [1303 rows x 2 columns]

# %%
df["Gpu_Brand "]=v[0]

# %%
df.head(2)
# Out:
#   Company   TypeName  Inches  Ram               Memory  \
# 0   Apple  Ultrabook    13.3    8            128GB SSD
# 1   Apple  Ultrabook    13.3    8  128GB Flash Storage
#
#                             Gpu  OpSys  Weight       Price  IPS  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832    1            0
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232    0            0
#
#   x_resolution y_resolution  Intel  AMD  SSD  HDD  Flash  Nvidia Gpu_Brand
# 0         2560         1600      1    0    1    0      0       0      Intel
# 1         1440          900      1    0    0    0      1       0      Intel

# %%
def Gpu_series_cat(variable):
    list1=variable.split()
    for value in list1:
        if value in ["Gtx","Iris","Radeon","GeForce","GeForce GTX","Quadro","FirePro","Mali"]:
            return value
    else:
        return "other"

# %%
df["Gpu_series"]=df["Gpu"].apply(Gpu_series_cat)

# %%
df.head(3)
# Out:
#   Company   TypeName  Inches  Ram               Memory  \
# 0   Apple  Ultrabook    13.3    8            128GB SSD
# 1   Apple  Ultrabook    13.3    8  128GB Flash Storage
# 2      HP   Notebook    15.6    8            256GB SSD
#
#                             Gpu  OpSys  Weight       Price  IPS  ...  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832    1  ...
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232    0  ...
# 2         Intel HD Graphics 620  No OS    1.86  30636.0000    0  ...
#
#    x_resolution y_resolution Intel  AMD  SSD  HDD  Flash  Nvidia  Gpu_Brand   \
# 0          2560         1600     1    0    1    0      0       0       Intel
# 1          1440          900     1    0    0    0      1       0       Intel
# 2          1920         1080     1    0    1    0      0       0       Intel
#
#   Gpu_series
# 0       Iris
# 1      other
# 2      other
#
# [3 rows x 21 columns]

# %%
df["OpSys"].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
df["Windows"]=df["OpSys"].apply(lambda x:1 if "Windows" in x else 0)

# %%
def Os_cat(os_name):
    if os_name == "Windows 10" or "Windows 7" or "Windows 10 S ":
        return "Windows"
    elif os_name == "macOS" or "Mac OS X ":
        return "mac"
    elif os_name == "Linux":
        return "Linux"
    else:
        return "no os"

# %%
df["os_name"]=df["OpSys"].apply(Os_cat)

# %%
df
# Out:
#      Company            TypeName  Inches  Ram               Memory  \
# 0      Apple           Ultrabook    13.3    8            128GB SSD
# 1      Apple           Ultrabook    13.3    8  128GB Flash Storage
# 2         HP            Notebook    15.6    8            256GB SSD
# 3      Apple           Ultrabook    15.4   16            512GB SSD
# 4      Apple           Ultrabook    13.3    8            256GB SSD
# ...      ...                 ...     ...  ...                  ...
# 1298  Lenovo  2 in 1 Convertible    14.0    4            128GB SSD
# 1299  Lenovo  2 in 1 Convertible    13.3   16            512GB SSD
# 1300  Lenovo            Notebook    14.0    2   64GB Flash Storage
# 1301      HP            Notebook    15.6    6              1TB HDD
# 1302    Asus            Notebook    15.6    4            500GB HDD
#
#                                Gpu       OpSys  Weight        Price  IPS  ...  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832    1  ...
# ...

# %%
df.drop(columns=["os_name"],inplace=True)

# %%
df.info()

# %%
df["x_resolution"]=df["x_resolution"].astype("int")
df["y_resolution"]=df["y_resolution"].astype("int")

# %%
df["PPI"]=((((df["x_resolution"]**2)+(df["y_resolution"]**2))**0.5)/df["Inches"])

# %%
df
# Out:
#      Company            TypeName  Inches  Ram               Memory  \
# 0      Apple           Ultrabook    13.3    8            128GB SSD
# 1      Apple           Ultrabook    13.3    8  128GB Flash Storage
# 2         HP            Notebook    15.6    8            256GB SSD
# 3      Apple           Ultrabook    15.4   16            512GB SSD
# 4      Apple           Ultrabook    13.3    8            256GB SSD
# ...      ...                 ...     ...  ...                  ...
# 1298  Lenovo  2 in 1 Convertible    14.0    4            128GB SSD
# 1299  Lenovo  2 in 1 Convertible    13.3   16            512GB SSD
# 1300  Lenovo            Notebook    14.0    2   64GB Flash Storage
# 1301      HP            Notebook    15.6    6              1TB HDD
# 1302    Asus            Notebook    15.6    4            500GB HDD
#
#                                Gpu       OpSys  Weight        Price  IPS  ...  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832    1  ...
# ...

# %%
df.

# %%
df.drop(columns=["x_resolution"],inplace=True)

# %%
df.drop(columns=["y_resolution"],inplace=True)

# %%
df1=pd.read_csv("C:\\Users\\magar\\OneDrive\\Desktop\\PROGRAMM\\Data Science\\train.csv")
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.shape
# Out:
# (891, 12)

# %%
df1["Cabin"]
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %% [markdown]
# #### @ Handling the missing values :
#
#    - Missing value:na,nan,no value
#    - If we have a missing value in the datset the ML model will not do the proper prediction
#    - So there is need of handling the missing values
#
# #### 1. Drop the missing value:
#
#   - Syntax : dataframe.dropna()
#   - It will iterate over the row wherever it found the missing value in the column it will simply delete that row.
#   - axis=0--by default
#   - axis=1:columns
#   - how=any/all
#   - By default its any
#   - Whenever we are using multiple columns in the subset arguments it will perform or operation

# %%
df1.dropna().shape
# Out:
# (183, 12)

# %%
df1.dropna(axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df1.dropna(axis=0,how='all')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1["Cabin"].dropna(inplace=True)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.dropna(axis=0,subset=["Cabin"],inplace=True)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.dropna(axis=0,subset=["Cabin","Embarked"],inplace=True)

# %%
import pandas as pd
import numpy as np

# %%
data={
    "A":[12,np.nan,np.nan,np.nan,23],
    "B":[2,np.nan,3,np.nan,3],
    "C":[34,45,np.nan,np.nan,np.nan],
    "D":[np.nan,np.nan,np.nan,np.nan,np.nan]
}

# %%
df=pd.DataFrame(data)
df
# Out:
#       A    B     C   D
# 0  12.0  2.0  34.0 NaN
# 1   NaN  NaN  45.0 NaN
# 2   NaN  3.0   NaN NaN
# 3   NaN  NaN   NaN NaN
# 4  23.0  3.0   NaN NaN

# %% [markdown]
# ##### @ Thrash : It will keep rows of the non missing value of thrash and it will delete the reamining rows

# %%
df.dropna(thresh=2)
# Out:
#       A    B     C   D
# 0  12.0  2.0  34.0 NaN
# 4  23.0  3.0   NaN NaN

# %%
df1.fillna(0)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1["Cabin"].fillna(0)
# Out:
# 1              C85
# 3             C123
# 6              E46
# 10              G6
# 11            C103
#           ...
# 871            D35
# 872    B51 B53 B55
# 879            C50
# 887            B42
# 889           C148
# Name: Cabin, Length: 202, dtype: object

# %%
df1["Embarked"].fillna("not specified")
# Out:
# 1      C
# 3      S
# 6      S
# 10     S
# 11     S
#       ..
# 871    S
# 872    S
# 879    C
# 887    S
# 889    C
# Name: Embarked, Length: 202, dtype: object

# %%
df1["Embarked"].fillna(df1["Embarked"].mode())
# Out:
# 1      C
# 3      S
# 6      S
# 10     S
# 11     S
#       ..
# 871    S
# 872    S
# 879    C
# 887    S
# 889    C
# Name: Embarked, Length: 202, dtype: object

# %%
df1["Age"].mean()
# Out:
# 35.6744262295082

# %%
df1["Cabin"].fillna(df1["Cabin"].mode())
# Out:
# 1              C85
# 3             C123
# 6              E46
# 10              G6
# 11            C103
#           ...
# 871            D35
# 872    B51 B53 B55
# 879            C50
# 887            B42
# 889           C148
# Name: Cabin, Length: 202, dtype: object

# %%
df1["Cabin"].unique()
# Out:
# array(['C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6', 'C23 C25 C27',
#        'B78', 'D33', 'B30', 'C52', 'C83', 'F33', 'F G73', 'E31', 'A5',
#        'D10 D12', 'D26', 'C110', 'B58 B60', 'E101', 'F E69', 'D47', 'B86',
#        'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4', 'A32', 'B4', 'B80',
#        'A31', 'D36', 'D15', 'C93', 'C78', 'D35', 'C87', 'B77', 'E67',
#        'B94', 'C125', 'C99', 'C118', 'D7', 'A19', 'B49', 'D', 'C22 C26',
#        'C106', 'C65', 'E36', 'C54', 'B57 B59 B63 B66', 'C7', 'E34', 'C32',
#        'B18', 'C124', 'C91', 'E40', 'T', 'C128', 'D37', 'B35', 'E50',
#        'C82', 'B96 B98', 'E10', 'E44', 'A34', 'C104', 'C111', 'C92',
#        'E38', 'D21', 'E12', 'E63', 'A14', 'B37', 'C30', 'D20', 'B79',
#        'E25', 'D46', 'B73', 'C95', 'B38', 'B39', 'B22', 'C86', 'C70',
#        'A16', 'C101', 'C68', 'A10', 'E68', 'B41', 'A20', 'D19', 'D50',
#        'D9', 'A23', 'B50', 'A26', 'D48', 'E58', 'C126', 'B71',
# ...

# %%
df1["Age"].fillna(method='ffill')
# Out:
# C:\Users\magar\AppData\Local\Temp\ipykernel_40660\3935931440.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1["Age"].fillna(method='ffill')
# 1      38.0
# 3      35.0
# 6      54.0
# 10      4.0
# 11     58.0
#        ...
# 871    47.0
# 872    33.0
# 879    56.0
# 887    19.0
# 889    26.0
# Name: Age, Length: 202, dtype: float64

# %%
df1["Age"].fillna(method='bfill')
# Out:
# C:\Users\magar\AppData\Local\Temp\ipykernel_40660\3533700952.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1["Age"].fillna(method='bfill')
# 1      38.0
# 3      35.0
# 6      54.0
# 10      4.0
# 11     58.0
#        ...
# 871    47.0
# 872    33.0
# 879    56.0
# 887    19.0
# 889    26.0
# Name: Age, Length: 202, dtype: float64

# %%
s1=pd.Series([20,np.nan,np.nan,np.nan,40])
s2=pd.Series([10,np.nan,np.nan,30,40])

# %%
s1.fillna(method='ffill')
# Out:
# C:\Users\magar\AppData\Local\Temp\ipykernel_40660\1308815330.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   s1.fillna(method='ffill')
# 0    20.0
# 1    20.0
# 2    20.0
# 3    20.0
# 4    40.0
# dtype: float64

# %%
s2.fillna(method='bfill')
# Out:
# C:\Users\magar\AppData\Local\Temp\ipykernel_40660\3054391257.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   s2.fillna(method='bfill')
# 0    10.0
# 1    30.0
# 2    30.0
# 3    30.0
# 4    40.0
# dtype: float64

# %%
s3=pd.Series([np.nan,45,np.nan,30,40])
s3.fillna(method='bfill')
# Out:
# C:\Users\magar\AppData\Local\Temp\ipykernel_40660\971891881.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   s3.fillna(method='bfill')
# 0    45.0
# 1    45.0
# 2    30.0
# 3    30.0
# 4    40.0
# dtype: float64

# %%
person={
    "first_name":["Kiran","Komal","Varsha"],
    "last_name":["Magare","Mali","joshi"],
    "email":["abc@gmail.com","sdf@yahoo.com","pqr@hotmail.com"]
}

# %%
data1=pd.DataFrame(person)
data1
# Out:
#   first_name last_name            email
# 0      Kiran    Magare    abc@gmail.com
# 1      Komal      Mali    sdf@yahoo.com
# 2     Varsha     joshi  pqr@hotmail.com

# %%
data1["full_name"]=data1["first_name"]+" "+data1["last_name"]

# %%
data1
# Out:
#              email     full_name
# 0    abc@gmail.com  Kiran Magare
# 1    sdf@yahoo.com    Komal Mali
# 2  pqr@hotmail.com  Varsha joshi

# %%
data1.drop(columns=["first_name"],inplace=True)

# %%
data1.drop(columns=["last_name"],inplace=True)

# %%
a=data1["full_name"].str.split(" ",n=1,expand=True)

# %%
data1["first_name"]=a[0]
data1["last_name"]=a[1]

# %%
data1
# Out:
#              email first_name last_name
# 0    abc@gmail.com      Kiran    Magare
# 1    sdf@yahoo.com      Komal      Mali
# 2  pqr@hotmail.com     Varsha     joshi

# %%
data1.drop(columns=["full_name"],inplace=True)

# %%
d2=pd.concat([data1,data3],ignore_index=True)
d2
# Out:
#              email first_name last_name
# 0    abc@gmail.com      Kiran    Magare
# 1    sdf@yahoo.com      Komal      Mali
# 2  pqr@hotmail.com     Varsha     joshi
# 3              NaN     Khushi       NaN

# %%
data2={
    "first_name":"Khushi"
}

# %%
data3=pd.DataFrame([data2])
data3
# Out:
#   first_name
# 0     Khushi

# %%
df2=pd.read_csv("C:\\Users\\magar\\Downloads\\quikr_car.csv")
df2
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
df2.columns
# Out:
# Index(['name', 'company', 'year', 'Price', 'kms_driven', 'fuel_type'], dtype='object')

# %%
df2["year"]
# Out:
# 0      2007
# 1      2006
# 2      2018
# 3      2014
# 4      2014
#        ...
# 887    zest
# 888    2018
# 889    2013
# 890    2014
# 891    2014
# Name: year, Length: 892, dtype: object

# %%
df2=df2[df2["year"].str.isnumeric()]
df2["year"]=df2["year"].astype(int)
# Out:
# C:\Users\magar\AppData\Local\Temp\ipykernel_43180\3162306984.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["year"]=df2["year"].astype(int)

# %%
df2["year"].unique()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 842 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        842 non-null    object
#  1   company     842 non-null    object
#  2   year        842 non-null    int32
#  3   Price       842 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: int32(1), object(5)
# memory usage: 42.8+ KB

# %%
import pandas as pd
import numpy as np

# %%
df2["fuel_type"].isnull().sum()
# Out:
# 5

# %%
df2["fuel_type"].fillna(method='ffill')
# Out:
# C:\Users\magar\AppData\Local\Temp\ipykernel_43180\3144055253.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2["fuel_type"].fillna(method='ffill')
# 0      Petrol
# 1      Diesel
# 2      Petrol
# 3      Petrol
# 4      Diesel
#         ...
# 886    Petrol
# 888    Diesel
# 889    Diesel
# 890    Diesel
# 891    Diesel
# Name: fuel_type, Length: 842, dtype: object

# %%
df2["fuel_type"].value_counts()
# Out:
# fuel_type
# Petrol    440
# Diesel    395
# LPG         2
# Name: count, dtype: int64

# %%
s=pd.Series([34,45,67,99])
s
# Out:
# 0    34
# 1    45
# 2    67
# 3    99
# dtype: int64

# %%
l=s.to_list()
l
# Out:
# [34, 45, 67, 99]

# %%
df2["Price"].tolist()
# Out:
# ['80,000',
#  '4,25,000',
#  'Ask For Price',
#  '3,25,000',
#  '5,75,000',
#  'Ask For Price',
#  '1,75,000',
#  '1,90,000',
#  '8,30,000',
#  '2,50,000',
#  '1,82,000',
#  '3,15,000',
#  '4,15,000',
#  '3,20,000',
#  '80,000',
#  '4,25,000',
#  '10,00,000',
#  '5,00,000',
#  '3,50,000',
#  '1,60,000',
#  '3,50,000',
#  '3,10,000',
#  '75,000',
#  '1,00,000',
#  '1,00,000',
#  '1,00,000',
#  '1,90,000',
#  '2,90,000',
#  '95,000',
#  '1,80,000',
#  '3,85,000',
#  '2,50,000',
#  '1,80,000',
#  '1,05,000',
#  '1,05,000',
#  '6,50,000',
#  '6,89,999',
#  '4,48,000',
#  '5,49,000',
#  '5,01,000',
#  '4,89,999',
#  '2,80,000',
#  '2,50,000',
#  '3,49,999',
#  '2,84,999',
#  '3,45,000',
#  '4,99,999',
#  '2,35,000',
#  '2,49,999',
#  '14,75,000',
#  '1,80,000',
#  '3,85,000',
#  '2,50,000',
#  '1,80,000',
#  '1,05,000',
#  '1,05,000',
#  '3,95,000',
#  '2,20,000',
#  '1,70,000',
#  '85,000',
#  '1,75,000',
#  '1,90,000',
#  '2,00,000',
#  '8,30,000',
#  '2,00,000',
#  '5,70,000',
# ...

# %%
df2.values.tolist()
# Out:
# [['Hyundai Santro Xing XO eRLX Euro III',
#   'Hyundai',
#   '2007',
#   '80,000',
#   '45,000 kms',
#   'Petrol'],
#  ['Mahindra Jeep CL550 MDI',
#   'Mahindra',
#   '2006',
#   '4,25,000',
#   '40 kms',
#   'Diesel'],
#  ['Maruti Suzuki Alto 800 Vxi',
#   'Maruti',
#   '2018',
#   'Ask For Price',
#   '22,000 kms',
#   'Petrol'],
#  ['Hyundai Grand i10 Magna 1.2 Kappa VTVT',
#   'Hyundai',
#   '2014',
#   '3,25,000',
#   '28,000 kms',
#   'Petrol'],
#  ['Ford EcoSport Titanium 1.5L TDCi',
#   'Ford',
#   '2014',
#   '5,75,000',
#   '36,000 kms',
#   'Diesel'],
#  ['Ford EcoSport Titanium 1.5L TDCi',
#   'Ford',
#   '2015',
#   'Ask For Price',
#   '59,000 kms',
#   'Diesel'],
#  ['Ford Figo', 'Ford', '2012', '1,75,000', '41,000 kms', 'Diesel'],
#  ['Hyundai Eon', 'Hyundai', '2013', '1,90,000', '25,000 kms', 'Petrol'],
#  ['Ford EcoSport Ambiente 1.5L TDCi',
#   'Ford',
#   '2016',
#   '8,30,000',
#   '24,530 kms',
#   'Diesel'],
#  ['Maruti Suzuki Alto K10 VXi AMT',
#   'Maruti',
# ...

# %%
df=pd.read_csv("C:\\Users\\magar\\Downloads\\Bengaluru_House_Data.csv")
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
df["BHK"]=df["size"].str.replace("BHK","")
df["BHK"]
# Out:
# 0               2
# 1        4 Bedroom
# 2               3
# 3               3
# 4               2
#            ...
# 13315    5 Bedroom
# 13316           4
# 13317           2
# 13318           4
# 13319           1
# Name: BHK, Length: 13320, dtype: object

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price        BHK
# ...

# %%
df.drop(columns=["area_type","availability","society","balcony"],inplace=True)

# %%
df
# Out:
#                        location       size total_sqft  bath   price        BHK
# 0      Electronic City Phase II      2 BHK       1056   2.0   39.07         2
# 1              Chikka Tirupathi  4 Bedroom       2600   5.0  120.00  4 Bedroom
# 2                   Uttarahalli      3 BHK       1440   2.0   62.00         3
# 3            Lingadheeranahalli      3 BHK       1521   3.0   95.00         3
# 4                      Kothanur      2 BHK       1200   2.0   51.00         2
# ...                         ...        ...        ...   ...     ...        ...
# 13315                Whitefield  5 Bedroom       3453   4.0  231.00  5 Bedroom
# 13316             Richards Town      4 BHK       3600   5.0  400.00         4
# 13317     Raja Rajeshwari Nagar      2 BHK       1141   2.0   60.00         2
# 13318           Padmanabhanagar      4 BHK       4689   4.0  488.00         4
# 13319              Doddathoguru      1 BHK        550   1.0   17.00         1
#
# [13320 rows x 6 columns]

# %%
df.drop(columns=["size"],inplace=True)

# %%
df["BHK"]=df["BHK"].str.replace("Bedroom","")

# %%
df["BHK"].isnull().sum()
# Out:
# 16

# %%
df["BHK"].fillna(method='ffill')
# Out:
# C:\Users\magar\AppData\Local\Temp\ipykernel_20344\757718829.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["BHK"].fillna(method='ffill')
# 0        2
# 1        4
# 2        3
# 3        3
# 4        2
#          ..
# 13315    5
# 13316    4
# 13317    2
# 13318    4
# 13319    1
# Name: BHK, Length: 13320, dtype: object

# %%
df["total_sqft"].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
def square_feet(n):
    result=x.split("-")
    if len(list1)==2:
        
    else:
        return n

# %%
df["Price_persqft"]=

# %%
df["price"].isnull().sum()
# Out:
# 0

# %%
import pandas as pd
import numpy as np

# %%
ds=pd.DataFrame({
    "Coach":["ac56","ac67","ac34","ac43","ac30"]})
ds
# Out:
#   Coach
# 0  ac56
# 1  ac67
# 2  ac34
# 3  ac43
# 4  ac30

# %%
import regex
ds["numberic"]=ds["Coach"].str.replace("[^\d]","",regex=True)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\magar\AppData\Local\Temp\ipykernel_20344\3045773635.py:2: SyntaxWarning: invalid escape sequence '\d'
#   ds["numberic"]=ds["Coach"].str.replace("[^\d]","",regex=True)

# %%
ds
# Out:
#   Coach numberic Categorical
# 0  ac56       56          ac
# 1  ac67       67          ac
# 2  ac34       34          ac
# 3  ac43       43          ac
# 4  ac30       30          ac

# %%
ds["Categorical"]=ds["Coach"].str.replace("[\d]","",regex=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\magar\AppData\Local\Temp\ipykernel_20344\1066473477.py:1: SyntaxWarning: invalid escape sequence '\d'
#   ds["Categorical"]=ds["Coach"].str.replace("[\d]","",regex=True)

# %%
ds1=pd.DataFrame({
    "rank":[34,56,1,"A",58,"D","E"]
})
ds1
# Out:
#   rank
# 0   34
# 1   56
# 2    1
# 3    A
# 4   58
# 5    D
# 6    E

# %%
ds1["rank_num"]=ds1["rank"].apply(lambda x:int(x) if str(x).isnumeric() else None)
ds1["rank_cat"]=ds1["rank"].apply(lambda )

# %%
ds1
# Out:
#   rank  rank_num rank_cat
# 0   34      34.0      NaN
# 1   56      56.0      NaN
# 2    1       1.0      NaN
# 3    A       NaN        A
# 4   58      58.0      NaN
# 5    D       NaN        D
# 6    E       NaN        E

# %%
df=pd.read_csv("C:\\Users\\magar\\Downloads\\hr.csv")
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
#convert it into 2 list numeric and categorical
ds1.values.tolist()
# Out:
# [[34, 34.0, nan],
#  [56, 56.0, nan],
#  [1, 1.0, nan],
#  ['A', nan, 'A'],
#  [58, 58.0, nan],
#  ['D', nan, 'D'],
#  ['E', nan, 'E']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df["Attrition"].isnull().sum()
# Out:
# 0

# %%
df["A_numeric"]=df["Attrition"].apply(lambda x:1 if x=="Yes" else 0 )

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df["A_numeric"].astype(int)
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: A_numeric, Length: 1470, dtype: int32

# %%
df["BusinessTravel"].value_counts()
# Out:
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64

# %%
df["Bt_numeric"]=df["BusinessTravel"].apply(lambda x:0 if x=='Travel_Rarely' else(1 if x=='Travel_Frequently' else 2))

# %%
df.drop(columns=["Attrition"],inplace=True)

# %%
df.drop(columns=["BusinessTravel"],inplace=True)

# %%
df["Department"].value_counts()
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
df["Dep_numeric"]=df["Department"].apply(lambda x:0 if x=='Research & Development' else(1 if x=='Sales ' else 2))

# %%
df.drop(columns=["Department"],inplace=True)

# %%
df["EducationField"].value_counts()
# Out:
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64

# %%
df["Edu_numeric"]=df["EducationField"].apply(lambda x:0 if x=='Life Sciences' else(1 if x=='Medical' else (2 if x=="Marketing" else (3 if x=="Technical Degree" else(4 if x=="Other" else 5)))))

# %%
df.drop(columns=["EducationField"],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   DailyRate                 1470 non-null   int64
#  2   DistanceFromHome          1470 non-null   int64
#  3   Education                 1470 non-null   int64
#  4   EmployeeCount             1470 non-null   int64
#  5   EmployeeNumber            1470 non-null   int64
#  6   EnvironmentSatisfaction   1470 non-null   int64
#  7   Gender                    1470 non-null   object
#  8   HourlyRate                1470 non-null   int64
#  9   JobInvolvement            1470 non-null   int64
#  10  JobLevel                  1470 non-null   int64
#  11  JobRole                   1470 non-null   object
#  12  JobSatisfaction           1470 non-null   int64
#  13  MaritalStatus             1470 non-null   object
# ...

# %%
df["JobRole"].value_counts()
# Out:
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64

# %%
df["JobRole_num"]=df["JobRole"].apply(lambda x:0 if x=="Sales Executive" else(1 if x=="Research Scientist" else(2 if x=="Laboratory Technician" else(3 if x=="Manufacturing Director" else(4 if x=="Healthcare Representative" else(5 if x=="Manager" else(6 if x=="Sales Representative" else(7 if x=="Research Director" else 8))))) )))

# %%
df["MaritalStatus"].value_counts()
# Out:
# MaritalStatus
# Married     673
# Single      470
# Divorced    327
# Name: count, dtype: int64

# %%
df["MaritalStatus_num"]=df["MaritalStatus"].apply(lambda x:0 if x=="Married" else(1 if x=="Single" else 2))

# %%
df["OverTime"].value_counts()
# Out:
# OverTime
# No     1054
# Yes     416
# Name: count, dtype: int64

# %%
df["OverTime_num"]=df["OverTime"].apply(lambda x:0 if x=="No" else 1)

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64

# %%
df["Gender_num"]=df["Gender"].apply(lambda x:0 if x=="Male" else 1)

# %%
df["Over18"].value_counts()
# Out:
# Over18
# Y    1470
# Name: count, dtype: int64

# %%
df["Over18_num"]=df["Over18"].apply(lambda x:0 if x=="Y" else 1)

# %%
df.drop(columns=["Over18","Gender","OverTime","MaritalStatus"],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   DailyRate                 1470 non-null   int64
#  2   DistanceFromHome          1470 non-null   int64
#  3   Education                 1470 non-null   int64
#  4   EmployeeCount             1470 non-null   int64
#  5   EmployeeNumber            1470 non-null   int64
#  6   EnvironmentSatisfaction   1470 non-null   int64
#  7   HourlyRate                1470 non-null   int64
#  8   JobInvolvement            1470 non-null   int64
#  9   JobLevel                  1470 non-null   int64
#  10  JobSatisfaction           1470 non-null   int64
#  11  MonthlyIncome             1470 non-null   int64
#  12  MonthlyRate               1470 non-null   int64
#  13  NumCompaniesWorked        1470 non-null   int64
# ...

# %%
df.drop(columns=["JobRole"],inplace=True)

# %%
df.to_csv('hr_processing.csv',index=False)

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("C:\\Users\\magar\\Downloads\\Bike_Price_Prediction.xlsx")
df
# Out:
#      S.no Bike_company       Bike_model  Manufactured_year  Engine_warranty  \
# 0       1        Bajaj      Avenger 220               2020              5.0
# 1       2          TVS       Apache RTR               2020              5.0
# 2       3         Hero          Passion               2020              5.0
# 3       4        Honda        Activa 3G               2020              5.0
# 4       5       Suzuki           Access               2020              5.0
# ..    ...          ...              ...                ...              ...
# 303   304       Bgauss        Bgauss B8               2017              3.0
# 304   305       Bgauss  Bgauss Radiator               2017              3.0
# 305   306       Bgauss     Bgauss Razor               2017              3.0
# 306   307       Bgauss     Bgauss Flash               2017              3.0
# 307   308       Bgauss      Bgauss Hash               2017              3.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308 entries, 0 to 307
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   S.no                308 non-null    int64
#  1   Bike_company        308 non-null    object
#  2   Bike_model          308 non-null    object
#  3   Manufactured_year   308 non-null    int64
#  4   Engine_warranty     306 non-null    float64
#  5   Engine_type         308 non-null    object
#  6   Fuel_type           308 non-null    object
#  7   CC(Cubic capacity)  308 non-null    object
#  8   Fuel_Capacity       307 non-null    object
#  9   Price               308 non-null    int64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 24.2+ KB

# %%
df.shape[1]
# Out:
# 10

# %%
df.columns
# Out:
# Index(['S.no', 'Bike_company', 'Bike_model', 'Manufactured_year',
#        'Engine_warranty', 'Engine_type', 'Fuel_type', 'CC(Cubic capacity)',
#        'Fuel_Capacity', 'Price'],
#       dtype='object')

# %%
df["Bike_company"].value_counts()
# Out:
# Bike_company
# Suzuki                      20
# Yamaha                      20
# Hero                        19
# Ducati                      19
# Mahindra                    17
# Honda                       16
# Triumph                     15
# KTM                         15
# Lectro Electric             13
# Kawasaki                    13
# Bajaj                       12
# Banelli                     12
# BMW                         12
# Harley Davidson             11
# Li-ion Elektrik Solution    11
# CFMoto                      11
# Royal Enfield               10
# Ather Energy                 9
# Okinawa                      9
# TVS                          8
# Revolt Motors                8
# Bgauss                       8
# Jawa                         7
# 22Kymco                      7
# Odysse                       6
# Name: count, dtype: int64

# %%
df['Bike_model'].value_counts()
# Out:
# Bike_model
# Bullet         6
# Gixer          5
# Glamour        5
# Fascino        5
# Ninja          5
#               ..
# GS 990         1
# Intruder       1
# Dragon         1
# Monster        1
# Bgauss Hash    1
# Name: count, Length: 237, dtype: int64

# %%
df.isnull().sum()
# Out:
# S.no                  0
# Bike_company          0
# Bike_model            0
# Manufactured_year     0
# Engine_warranty       2
# Engine_type           0
# Fuel_type             0
# CC(Cubic capacity)    0
# Fuel_Capacity         1
# Price                 0
# dtype: int64

# %%
df["Engine_warranty"].unique()
# Out:
# array([ 5., 10.,  2.,  4., nan,  6.,  7.,  8.,  3., 50.,  9., 12., 13.,
#        14.])

# %%
df.fillna(df["Engine_warranty"].mean(),inplace=True)

# %%
df["Engine_warranty"].isnull().sum()
# Out:
# 0

# %%
df["Fuel_Capacity"]=df["Fuel_Capacity"]

# %%
df["Manufactured_year"].unique()
# Out:
# array([2020, 2019, 2018, 2017, 2016, 2011, 2012, 2013, 2014, 2015, 1840,
#         202, 2050, 1790], dtype=int64)

# %%
df["Engine_type"].value_counts()
# Out:
# Engine_type
# Boxer                 97
# Single                81
# V-twin                81
# Two-Stroke            27
# Dual Stroke           15
# Oxidiser-Air inlet     7
# Name: count, dtype: int64

# %%
df["Engine_type_num"]=df["Engine_type"].apply(lambda x:0 if x=='Boxer' else(1 if x=='Single' else (2 if x=="V-twin" else (3 if x=="Two-Stroke" else (4 if x=="Dual Stroke" else 5)))))

# %%
df.drop(columns=["Engine_type"],inplace=True)

# %%
df["Fuel_type"].value_counts()
# Out:
# Fuel_type
# Petrol         258
# Electricity     50
# Name: count, dtype: int64

# %%
df["Fuel_type_num"]=df["Fuel_type"].apply(lambda x:0 if x=="Petrol" else 1)

# %%
df["CC(Cubic capacity)"]=df["CC(Cubic capacity)"].str.replace("CC","")

# %%
df.drop(columns=["Fuel_type"],inplace=True)

# %%
df["CC(Cubic capacity)"]=df["CC(Cubic capacity)"].astype("int")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308 entries, 0 to 307
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   S.no                308 non-null    int64
#  1   Bike_company        308 non-null    object
#  2   Bike_model          308 non-null    object
#  3   Manufactured_year   308 non-null    int64
#  4   Engine_warranty     308 non-null    float64
#  5   CC(Cubic capacity)  308 non-null    int32
#  6   Fuel_Capacity       308 non-null    object
#  7   Price               308 non-null    int64
#  8   Engine_type_num     308 non-null    int64
#  9   Fuel_type_num       308 non-null    int64
# dtypes: float64(1), int32(1), int64(5), object(3)
# memory usage: 23.0+ KB

# %%
df["Fuel_Capacity"].unique()
# Out:
# array(['10 Litres', '11 Litres', '12 Litres', '13 Litres', '14 Litres',
#        '15 Litres', '16 Litres', '17 Litres', '18 Litres', '19 Litres',
#        '20 Litres', '21 Litres', '22 Litres', '23 Litres', 'Battery',
#        6.032679738562091, '24 Litres', '25 Litres', '26 Litres',
#        '27 Litres', '28 Litres', '29 Litres', '30 Litres', '31 Litres',
#        '32 Litres', '33 Litres', '34 Litres', '35 Litres'], dtype=object)

# %%
df["Fuel_Capacity"] = df["Fuel_Capacity"].str.replace("Battery", "", case=False).str.strip()

# %%
df.dropna(axis=0,subset=["Fuel_Capacity"],inplace=True)

# %%
df["Fuel_Capacity"]=df["Fuel_Capacity"].str.replace("Litres","")

# %%
df
# Out:
#      S.no Bike_company       Bike_model  Manufactured_year  Engine_warranty  \
# 0       1        Bajaj      Avenger 220               2020              5.0
# 1       2          TVS       Apache RTR               2020              5.0
# 2       3         Hero          Passion               2020              5.0
# 3       4        Honda        Activa 3G               2020              5.0
# 4       5       Suzuki           Access               2020              5.0
# ..    ...          ...              ...                ...              ...
# 303   304       Bgauss        Bgauss B8               2017              3.0
# 304   305       Bgauss  Bgauss Radiator               2017              3.0
# 305   306       Bgauss     Bgauss Razor               2017              3.0
# 306   307       Bgauss     Bgauss Flash               2017              3.0
# 307   308       Bgauss      Bgauss Hash               2017              3.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 307 entries, 0 to 307
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   S.no                307 non-null    int64
#  1   Bike_company        307 non-null    object
#  2   Bike_model          307 non-null    object
#  3   Manufactured_year   307 non-null    int64
#  4   Engine_warranty     307 non-null    float64
#  5   CC(Cubic capacity)  307 non-null    int32
#  6   Fuel_Capacity       307 non-null    object
#  7   Price               307 non-null    int64
#  8   Engine_type_num     307 non-null    int64
#  9   Fuel_type_num       307 non-null    int64
# dtypes: float64(1), int32(1), int64(5), object(3)
# memory usage: 25.2+ KB

# %%
df.to_csv('Bike_Price_Prediction.csv',index=False)

# %%
df1=pd.read_csv("C:\\Users\\magar\\Downloads\\autos.csv",encoding="latin1")
df1
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dateCrawled          371528 non-null  object
#  1   name                 371528 non-null  object
#  2   seller               371528 non-null  object
#  3   offerType            371528 non-null  object
#  4   price                371528 non-null  int64
#  5   abtest               371528 non-null  object
#  6   vehicleType          333659 non-null  object
#  7   yearOfRegistration   371528 non-null  int64
#  8   gearbox              351319 non-null  object
#  9   powerPS              371528 non-null  int64
#  10  model                351044 non-null  object
#  11  kilometer            371528 non-null  int64
#  12  monthOfRegistration  371528 non-null  int64
#  13  fuelType             338142 non-null  object
#  14  brand                371528 non-null  object
# ...

# %%
df1.shape
# Out:
# (371528, 20)

# %%
a=df1["name"].str.split("_",n=1,expand=True)
a
# Out:
#                  0                                         1
# 0             Golf                                     3_1.6
# 1               A5                         Sportback_2.7_Tdi
# 2             Jeep                 Grand_Cherokee_"Overland"
# 3             GOLF                             4_1_4__3TÜRER
# 4            Skoda                  Fabia_1.4_TDI_PD_Classic
# ...            ...                                       ...
# 371523       Suche                      t4___vito_ab_6_sitze
# 371524       Smart           smart_leistungssteigerung_100ps
# 371525  Volkswagen                   Multivan_T4_TDI_7DC_UY2
# 371526          VW                       Golf_Kombi_1_9l_TDI
# 371527         BMW  M135i_vollausgestattet_NP_52.720____Euro
#
# [371528 rows x 2 columns]

# %%
df1["company_name"]=a[0]

# %%
df1
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
df1.drop(columns=["seller","offerType","abtest"],inplace=True)

# %%
df1.to_csv('Autos_process.csv',index=False)
